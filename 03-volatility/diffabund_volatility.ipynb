# %%
library(phyloseq, verbose=FALSE)
library(corncob, verbose=FALSE)
library(magrittr, verbose=FALSE)
library(ggplot2, verbose=FALSE)
# Out:
# Warning message:
# “package ‘magrittr’ was built under R version 4.1.3”

# %%
load("../02-diversity/master_phyloseq.RData")
ps.dat
# head(sample_data(ps.dat))
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 14111 taxa and 1960 samples ]
# sample_data() Sample Data:       [ 1960 samples by 22 sample variables ]
# tax_table()   Taxonomy Table:    [ 14111 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 14111 tips and 14109 internal nodes ]

# %% [markdown]
# ## 1. HUU kids

# %%
# head(tax_table(ps.dat))
# TO DO: ONLY LOOK AT ADULT H-CF SAMPLES?
ps.dat.glom <- ps.dat %>%
                phyloseq::subset_samples(hiv_status == "HUU") %>%
                tax_glom("V8")
ps.dat.glom
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 628 taxa and 615 samples ]
# sample_data() Sample Data:       [ 615 samples by 22 sample variables ]
# tax_table()   Taxonomy Table:    [ 628 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 628 tips and 627 internal nodes ]

# %%
# differential abundance analysis 
set.seed(234)
da_analysis <- differentialTest(formula = ~ visit_num,
                               phi.formula = ~ visit_num,
                               formula_null = ~ 1,
                               phi.formula_null = ~ visit_num,
                               test = "Wald",
                               boot = FALSE,
                               data = ps.dat.glom,
                               fdr_cutoff = 0.05)
da_analysis
# Out:
# Object of class differentialTest
#
# $p: p-values
# $p_fdr: FDR-adjusted p-values
# $significant_taxa: taxa names of the statistically significant taxa
# $significant_models: model summaries of the statistically significant taxa
# $all_models: all model summaries
# $restrictions_DA: covariates tested for differential abundance
# $restrictions_DV: covariates tested for differential variability
# $discriminant_taxa_DA: taxa for which at least one covariate associated with the abundance was perfectly discriminant
# $discriminant_taxa_DV: taxa for which at least one covariate associated with the dispersion was perfectly discriminant
#
# plot( ) to see a plot of tested coefficients from significant taxa

# %%
# plot results (modified from plot.differentialTest function in corncob)
# modified from plot_differentialTest.R in corncob
level <- c("V8")
x <- da_analysis

signif_taxa <- otu_to_taxonomy(x$significant_taxa, x$data, level = level)
signif_taxa <- gsub("_", " ", signif_taxa) # NOTE: ASV label no longer informative after glom
signif_taxa
var_per_mod <- length(x$restrictions_DA) + length(x$restrictions_DV)
total_var_count <- length(signif_taxa) * var_per_mod
# initialize empty dataframe
df <- as.data.frame(matrix(NA, nrow = total_var_count, ncol = 5))
colnames(df) <- c("x", "xmin", "xmax", "taxa", "variable")

qval <- stats::qnorm(.975)
restricts_mu <- attr(x$restrictions_DA, "index")
restricts_phi <- attr(x$restrictions_DV, "index")

# loop through models to populate dataframe
count <- 1
for (i in 1:length(x$significant_models)) {
  # Below from print_summary_bbdml, just to get coefficient names
  tmp <- x$significant_models[[i]]
  coefs.mu <- tmp$coefficients[1:tmp$np.mu,, drop = FALSE]
  rownames(coefs.mu) <- paste0(substring(rownames(coefs.mu), 4), " Differential Abundance")
  coefs.mu <- coefs.mu[restricts_mu,, drop = FALSE]

  coefs.phi <- tmp$coefficients[(tmp$np.mu + 1):nrow(tmp$coefficients),, drop = FALSE]
  rownames(coefs.phi) <- paste0(substring(rownames(coefs.phi), 5), " Differential Variability")
  coefs.phi <- coefs.phi[restricts_phi - tmp$np.mu,, drop = FALSE]

  coefs <- rbind(coefs.mu, coefs.phi)
  for (j in 1:var_per_mod) {
    df[count, 1:3] <- c(coefs[j, 1], coefs[j, 1] - qval * coefs[j, 2],
                      coefs[j, 1] + qval * coefs[j, 2])
    df[count, 4:5] <- c(signif_taxa[i], rownames(coefs)[j])
    count <- count + 1
    }
}

head(df)
# Out:
#                                                ASV6627
#                                 "Butyricimonas virosa"
#                                                 ASV950
#                             "Capnocytophaga granulosa"
#                                                 ASV361
# "Candidatus Saccharibacteria bacterium oral taxon 957"
#                                                 ASV245
#                          "Peptostreptococcus stomatis"
#                                                ASV1591
#                                "Abiotrophia defectiva"
#                                                 ASV454
#                              "Streptococcus cristatus"
#                                                  ASV54
#                              "Streptococcus sanguinis"
#                                                  ASV56
#                                  "Arachnia propionica"
#                                                ASV5208
#                             "unclassified Actinomyces"
#                                                 ASV663
#                                "Corynebacterium durum"
#                                                  ASV89
#                        "Eubacterium brachy ATCC 33089"
#                                                 ASV570
#                               "Mogibacterium diversum"
#   x          xmin       xmax
# 1 -4.6744830 -7.1076736 -2.2412923
# 2 -0.8773569 -3.6772984  1.9225847
# 3  0.5565003  0.2081881  0.9048125
# 4  0.6184669  0.2629299  0.9740039
# 5  2.5116476  1.4458065  3.5774887
# 6  1.6322433  0.6051442  2.6593423
#   taxa
# 1 Butyricimonas virosa
# 2 Butyricimonas virosa
# 3 Capnocytophaga granulosa
# 4 Capnocytophaga granulosa
# 5 Candidatus Saccharibacteria bacterium oral taxon 957
# 6 Candidatus Saccharibacteria bacterium oral taxon 957
#   variable
# 1 visit_num2 Differential Abundance
# 2 visit_num3 Differential Abundance
# 3 visit_num2 Differential Abundance
# 4 visit_num3 Differential Abundance
# 5 visit_num2 Differential Abundance
# 6 visit_num3 Differential Abundance

# %%
ggplot(df, aes(x = x, y = taxa)) +
  geom_vline(xintercept = 0, color = "gray50", lty = "dashed",
                          alpha = 0.75, lwd = 1) +
  geom_point() +
  geom_errorbarh(aes(xmin = xmin, xmax = xmax, colour = xmin<=0 & xmax <= 0| xmin>=0 & xmax >= 0), height = .3) +
  theme_bw() +
  facet_wrap(~variable, scales = "free_x", nrow = 1) +
  labs(title = "", x = "", y = "Taxa") +
  scale_y_discrete(limits = rev(df$taxa)) +
  scale_x_continuous(breaks = scales::pretty_breaks(n = 5)) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), legend.position="none") # turned off legend
# Out:
# plot without title

# %% [markdown]
# Differentially abundant taxa in HUU kids in visit one versus visit two and three

# %% [markdown]
# ## 2. HI kids

# %%
# head(tax_table(ps.dat))
ps.dat.glom <- ps.dat %>%
                phyloseq::subset_samples(hiv_status == "HI") %>%
                tax_glom("V8")
ps.dat.glom
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 628 taxa and 733 samples ]
# sample_data() Sample Data:       [ 733 samples by 22 sample variables ]
# tax_table()   Taxonomy Table:    [ 628 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 628 tips and 627 internal nodes ]

# %%
# differential abundance analysis 
set.seed(234)
da_analysis <- differentialTest(formula = ~ visit_num,
                               phi.formula = ~ visit_num,
                               formula_null = ~ 1,
                               phi.formula_null = ~ visit_num,
                               test = "Wald",
                               boot = FALSE,
                               data = ps.dat.glom,
                               fdr_cutoff = 0.05)

# %%
level <- c("V8")
x <- da_analysis

signif_taxa <- otu_to_taxonomy(x$significant_taxa, x$data, level = level)
signif_taxa <- gsub("_", " ", signif_taxa) # NOTE: ASV label no longer informative after glom
signif_taxa
var_per_mod <- length(x$restrictions_DA) + length(x$restrictions_DV)
total_var_count <- length(signif_taxa) * var_per_mod
# initialize empty dataframe
df <- as.data.frame(matrix(NA, nrow = total_var_count, ncol = 5))
colnames(df) <- c("x", "xmin", "xmax", "taxa", "variable")

qval <- stats::qnorm(.975)
restricts_mu <- attr(x$restrictions_DA, "index")
restricts_phi <- attr(x$restrictions_DV, "index")

# loop through models to populate dataframe
count <- 1
for (i in 1:length(x$significant_models)) {
  # Below from print_summary_bbdml, just to get coefficient names
  tmp <- x$significant_models[[i]]
  coefs.mu <- tmp$coefficients[1:tmp$np.mu,, drop = FALSE]
  rownames(coefs.mu) <- paste0(substring(rownames(coefs.mu), 4), " Differential Abundance")
  coefs.mu <- coefs.mu[restricts_mu,, drop = FALSE]

  coefs.phi <- tmp$coefficients[(tmp$np.mu + 1):nrow(tmp$coefficients),, drop = FALSE]
  rownames(coefs.phi) <- paste0(substring(rownames(coefs.phi), 5), " Differential Variability")
  coefs.phi <- coefs.phi[restricts_phi - tmp$np.mu,, drop = FALSE]

  coefs <- rbind(coefs.mu, coefs.phi)
  for (j in 1:var_per_mod) {
    df[count, 1:3] <- c(coefs[j, 1], coefs[j, 1] - qval * coefs[j, 2],
                      coefs[j, 1] + qval * coefs[j, 2])
    df[count, 4:5] <- c(signif_taxa[i], rownames(coefs)[j])
    count <- count + 1
    }
}

head(df)
# Out:
#                           ASV562                           ASV245
#       "Capnocytophaga granulosa"    "Peptostreptococcus stomatis"
#                          ASV1852                           ASV310
#          "Abiotrophia defectiva"        "Streptococcus cristatus"
#                            ASV54                            ASV22
#        "Streptococcus sanguinis"       "Gemella haemolysans M341"
#                           ASV116                          ASV3578
#                    "Clostridium"          "Schaalia odontolytica"
#                            ASV73                             ASV5
#    "Corynebacterium matruchotii"            "Rothia dentocariosa"
#                          ASV1899                            ASV89
#       "unclassified Selenomonas"  "Eubacterium brachy ATCC 33089"
#                           ASV570                          ASV4470
#         "Mogibacterium diversum"          "Mogibacterium pumilum"
#                            ASV59                           ASV942
#  "Lachnoanaerobaculum saburreum"           "Treponema socranskii"
#                           ASV150                           ASV353
#         "Campylobacter gracilis"                "Neisseria sicca"
#                           ASV167                           ASV957
# "Aggregatibacter sp. 2125159857"      "Prevotella saccharolytica"
#   x          xmin       xmax        taxa
# 1  0.5779346  0.2645533  0.89131593 Capnocytophaga granulosa
# 2  0.2831191 -0.0316794  0.59791770 Capnocytophaga granulosa
# 3 -1.1322575 -1.6073243 -0.65719067 Peptostreptococcus stomatis
# 4 -1.2291083 -1.7039252 -0.75429149 Peptostreptococcus stomatis
# 5 -0.6072608 -1.1483902 -0.06613137 Abiotrophia defectiva
# 6 -1.2268211 -1.8014667 -0.65217552 Abiotrophia defectiva
#   variable
# 1 visit_num2 Differential Abundance
# 2 visit_num3 Differential Abundance
# 3 visit_num2 Differential Abundance
# 4 visit_num3 Differential Abundance
# 5 visit_num2 Differential Abundance
# 6 visit_num3 Differential Abundance

# %%
ggplot(df, aes(x = x, y = taxa)) +
  geom_vline(xintercept = 0, color = "gray50", lty = "dashed",
                          alpha = 0.75, lwd = 1) +
  geom_point() +
  geom_errorbarh(aes(xmin = xmin, xmax = xmax, colour = xmin<=0 & xmax <= 0| xmin>=0 & xmax >= 0), height = .3) +
  theme_bw() +
  facet_wrap(~variable, scales = "free_x", nrow = 1) +
  labs(title = "", x = "", y = "Taxa") +
  scale_y_discrete(limits = rev(df$taxa)) +
  scale_x_continuous(breaks = scales::pretty_breaks(n = 5)) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), legend.position="none") # turned off legend
# Out:
# plot without title

# %% [markdown]
# ## 3. HEU kids

# %%
# head(tax_table(ps.dat))
ps.dat.glom <- ps.dat %>%
                phyloseq::subset_samples(hiv_status == "HEU") %>%
                tax_glom("V8")
ps.dat.glom
# differential abundance analysis 
set.seed(234)
da_analysis <- differentialTest(formula = ~ visit_num,
                               phi.formula = ~ visit_num,
                               formula_null = ~ 1,
                               phi.formula_null = ~ visit_num,
                               test = "Wald",
                               boot = FALSE,
                               data = ps.dat.glom,
                               fdr_cutoff = 0.05)
level <- c("V8")
x <- da_analysis

signif_taxa <- otu_to_taxonomy(x$significant_taxa, x$data, level = level)
signif_taxa <- gsub("_", " ", signif_taxa) # NOTE: ASV label no longer informative after glom
signif_taxa
var_per_mod <- length(x$restrictions_DA) + length(x$restrictions_DV)
total_var_count <- length(signif_taxa) * var_per_mod
# initialize empty dataframe
df <- as.data.frame(matrix(NA, nrow = total_var_count, ncol = 5))
colnames(df) <- c("x", "xmin", "xmax", "taxa", "variable")

qval <- stats::qnorm(.975)
restricts_mu <- attr(x$restrictions_DA, "index")
restricts_phi <- attr(x$restrictions_DV, "index")

# loop through models to populate dataframe
count <- 1
for (i in 1:length(x$significant_models)) {
  # Below from print_summary_bbdml, just to get coefficient names
  tmp <- x$significant_models[[i]]
  coefs.mu <- tmp$coefficients[1:tmp$np.mu,, drop = FALSE]
  rownames(coefs.mu) <- paste0(substring(rownames(coefs.mu), 4), " Differential Abundance")
  coefs.mu <- coefs.mu[restricts_mu,, drop = FALSE]

  coefs.phi <- tmp$coefficients[(tmp$np.mu + 1):nrow(tmp$coefficients),, drop = FALSE]
  rownames(coefs.phi) <- paste0(substring(rownames(coefs.phi), 5), " Differential Variability")
  coefs.phi <- coefs.phi[restricts_phi - tmp$np.mu,, drop = FALSE]

  coefs <- rbind(coefs.mu, coefs.phi)
  for (j in 1:var_per_mod) {
    df[count, 1:3] <- c(coefs[j, 1], coefs[j, 1] - qval * coefs[j, 2],
                      coefs[j, 1] + qval * coefs[j, 2])
    df[count, 4:5] <- c(signif_taxa[i], rownames(coefs)[j])
    count <- count + 1
    }
}

head(df)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 628 taxa and 612 samples ]
# sample_data() Sample Data:       [ 612 samples by 22 sample variables ]
# tax_table()   Taxonomy Table:    [ 628 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 628 tips and 627 internal nodes ]
#                                                 ASV732
#                             "Capnocytophaga granulosa"
#                                                 ASV546
#                                        "Bacteroidetes"
#                                                 ASV400
# "Candidatus Saccharibacteria bacterium oral taxon 488"
#                                                 ASV245
#                          "Peptostreptococcus stomatis"
#                                                 ASV298
#                              "Streptococcus cristatus"
#                                                  ASV54
#                              "Streptococcus sanguinis"
#                                                 ASV754
#                               "Streptococcus gordonii"
#                                                  ASV22
#                             "Gemella haemolysans M341"
#                                                 ASV347
#                                          "Clostridium"
#                                                ASV1346
#                                    "Selenomonas noxia"
#                                                  ASV89
#                        "Eubacterium brachy ATCC 33089"
#                                                 ASV362
#                       "Eubacterium nodatum ATCC 33099"
#                                                 ASV570
#                               "Mogibacterium diversum"
#                                                 ASV150
#                               "Campylobacter gracilis"
#                                                 ASV588
#                     "Haemophilus paraphrohaemolyticus"
#   x         xmin      xmax
# 1 0.5779849 0.2463793 0.9095904
# 2 0.5065762 0.1925510 0.8206014
# 3 1.0762189 0.2653631 1.8870748
# 4 1.6218516 0.8627859 2.3809172
# 5 1.3289463 0.7292277 1.9286648
# 6 1.5378426 0.9508880 2.1247973
#   taxa
# 1 Capnocytophaga granulosa
# 2 Capnocytophaga granulosa
# 3 Bacteroidetes
# 4 Bacteroidetes
# 5 Candidatus Saccharibacteria bacterium oral taxon 488
# 6 Candidatus Saccharibacteria bacterium oral taxon 488
#   variable
# 1 visit_num2 Differential Abundance
# 2 visit_num3 Differential Abundance
# 3 visit_num2 Differential Abundance
# 4 visit_num3 Differential Abundance
# 5 visit_num2 Differential Abundance
# 6 visit_num3 Differential Abundance

# %%
pdf("img/diffabund_vistnum.pdf")
ggplot(df, aes(x = x, y = taxa)) +
  geom_vline(xintercept = 0, color = "gray50", lty = "dashed",
                          alpha = 0.75, lwd = 1) +
  geom_point() +
  geom_errorbarh(aes(xmin = xmin, xmax = xmax, colour = xmin<=0 & xmax <= 0| xmin>=0 & xmax >= 0), height = .3) +
  theme_bw() +
  facet_wrap(~variable, scales = "free_x", nrow = 1) +
  labs(title = "", x = "", y = "Taxa") +
  scale_y_discrete(limits = rev(df$taxa)) +
  scale_x_continuous(breaks = scales::pretty_breaks(n = 5)) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), legend.position="none") # turned off legend
dev.off()

ggplot(df, aes(x = x, y = taxa)) +
  geom_vline(xintercept = 0, color = "gray50", lty = "dashed",
                          alpha = 0.75, lwd = 1) +
  geom_point() +
  geom_errorbarh(aes(xmin = xmin, xmax = xmax, colour = xmin<=0 & xmax <= 0| xmin>=0 & xmax >= 0), height = .3) +
  theme_bw() +
  facet_wrap(~variable, scales = "free_x", nrow = 1) +
  labs(title = "", x = "", y = "Taxa") +
  scale_y_discrete(limits = rev(df$taxa)) +
  scale_x_continuous(breaks = scales::pretty_breaks(n = 5)) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), legend.position="none") # turned off legend
# Out:
# png
#   2
# plot without title

# %% [markdown]
# ## 4. HIV status + visit one vs visit three

# %%
# head(tax_table(ps.dat))
ps.dat.glom <- ps.dat %>%
                phyloseq::subset_samples(visit_num == "1" | visit_num == "3") %>%
                tax_glom("V8")
ps.dat.glom
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 628 taxa and 1363 samples ]
# sample_data() Sample Data:       [ 1363 samples by 22 sample variables ]
# tax_table()   Taxonomy Table:    [ 628 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 628 tips and 627 internal nodes ]

# %%
# set HUU as base level factor 
sample_data(ps.dat.glom)$hiv_status <- factor(sample_data(ps.dat.glom)$hiv_status, levels=c("HUU", "HEU", "HI"))
# sample_data(ps.dat.glom)$hiv_status
sample_data(ps.dat.glom)$visit_num <- factor(sample_data(ps.dat.glom)$visit_num, levels=c("1", "3"))
# sample_data(ps.dat.glom)$visit_num

# %%
# differential abundance analysis 
set.seed(234)
da_analysis <- differentialTest(formula = ~ hiv_status + visit_num,
                               phi.formula = ~ hiv_status + visit_num,
                               formula_null = ~ 1,
                               phi.formula_null = ~ hiv_status + visit_num,
                               test = "Wald",
                               boot = FALSE,
                               data = ps.dat.glom,
                               fdr_cutoff = 0.001)
level <- c("V8")
x <- da_analysis

signif_taxa <- otu_to_taxonomy(x$significant_taxa, x$data, level = level)
signif_taxa <- gsub("_", " ", signif_taxa) # NOTE: ASV label no longer informative after glom
signif_taxa
var_per_mod <- length(x$restrictions_DA) + length(x$restrictions_DV)
total_var_count <- length(signif_taxa) * var_per_mod
# initialize empty dataframe
df <- as.data.frame(matrix(NA, nrow = total_var_count, ncol = 5))
colnames(df) <- c("x", "xmin", "xmax", "taxa", "variable")

qval <- stats::qnorm(.975)
restricts_mu <- attr(x$restrictions_DA, "index")
restricts_phi <- attr(x$restrictions_DV, "index")

# loop through models to populate dataframe
count <- 1
for (i in 1:length(x$significant_models)) {
  # Below from print_summary_bbdml, just to get coefficient names
  tmp <- x$significant_models[[i]]
  coefs.mu <- tmp$coefficients[1:tmp$np.mu,, drop = FALSE]
  rownames(coefs.mu) <- paste0(substring(rownames(coefs.mu), 4), " Differential Abundance")
  coefs.mu <- coefs.mu[restricts_mu,, drop = FALSE]

  coefs.phi <- tmp$coefficients[(tmp$np.mu + 1):nrow(tmp$coefficients),, drop = FALSE]
  rownames(coefs.phi) <- paste0(substring(rownames(coefs.phi), 5), " Differential Variability")
  coefs.phi <- coefs.phi[restricts_phi - tmp$np.mu,, drop = FALSE]

  coefs <- rbind(coefs.mu, coefs.phi)
  for (j in 1:var_per_mod) {
    df[count, 1:3] <- c(coefs[j, 1], coefs[j, 1] - qval * coefs[j, 2],
                      coefs[j, 1] + qval * coefs[j, 2])
    df[count, 4:5] <- c(signif_taxa[i], rownames(coefs)[j])
    count <- count + 1
    }
}

head(df)
# Out:
#                                                 ASV901
#    "Bacteroidetes bacterium oral taxon 272 str. F0290"
#                                                 ASV562
#                             "Capnocytophaga granulosa"
#                                                 ASV546
#                                        "Bacteroidetes"
#                                                 ASV400
# "Candidatus Saccharibacteria bacterium oral taxon 488"
#                                                 ASV245
#                          "Peptostreptococcus stomatis"
#                                                ASV1591
#                                "Abiotrophia defectiva"
#                                                 ASV298
#                              "Streptococcus cristatus"
#                                                ASV1160
#                                  "Streptococcus mitis"
#                                                  ASV54
#                              "Streptococcus sanguinis"
#                                                ASV6287
#                                 "Streptococcus downei"
#                                                 ASV109
#                                  "Gemella morbillorum"
#                                                  ASV22
#                             "Gemella haemolysans M341"
#                                                 ASV116
#                                          "Clostridium"
#                                                  ASV61
#                      "Leptotrichia sp. oral taxon 417"
#                                                ASV5643
#                       "Propionibacterium australiense"
#                                                ASV3578
#                                "Schaalia odontolytica"
#                                                ASV1817
#                             "Corynebacterium mustelae"
#                                                  ASV44
#                          "Corynebacterium matruchotii"
#                                                 ASV663
#                                "Corynebacterium durum"
#                                                ASV1477
#                                    "Selenomonas noxia"
#                                                  ASV89
#                        "Eubacterium brachy ATCC 33089"
#                                                 ASV570
#                               "Mogibacterium diversum"
#                                                  ASV85
#                                "Enterocloster bolteae"
#                                                 ASV167
#                       "Aggregatibacter sp. 2125159857"
#                                                 ASV157
#                                           "Prevotella"
#                                                ASV2059
#                                    "Prevotella shahii"
#                                                ASV6582
#                                     "Prevotella bivia"
#   x          xmin       xmax
# 1 -0.8160802 -1.8568204 0.22465997
# 2  1.2932455  0.4224288 2.16406220
# 3  0.6107358 -0.1500912 1.37156273
# 4 -0.1804078 -0.4174213 0.05660574
# 5 -0.1540106 -0.3920507 0.08402953
# 6  0.4580733  0.2689857 0.64716083
#   taxa
# 1 Bacteroidetes bacterium oral taxon 272 str. F0290
# 2 Bacteroidetes bacterium oral taxon 272 str. F0290
# 3 Bacteroidetes bacterium oral taxon 272 str. F0290
# 4 Capnocytophaga granulosa
# 5 Capnocytophaga granulosa
# 6 Capnocytophaga granulosa
#   variable
# 1 hiv_statusHEU Differential Abundance
# 2 hiv_statusHI Differential Abundance
# 3 visit_num3 Differential Abundance
# 4 hiv_statusHEU Differential Abundance
# 5 hiv_statusHI Differential Abundance
# 6 visit_num3 Differential Abundance

# %%
ggplot(df, aes(x = x, y = taxa)) +
  geom_vline(xintercept = 0, color = "gray50", lty = "dashed",
                          alpha = 0.75, lwd = 1) +
  geom_point() +
  geom_errorbarh(aes(xmin = xmin, xmax = xmax, colour = xmin<=0 & xmax <= 0| xmin>=0 & xmax >= 0), height = .3) +
  theme_bw() +
  facet_wrap(~variable, scales = "free_x", nrow = 1) +
  labs(title = "", x = "", y = "Taxa") +
  scale_y_discrete(limits = rev(df$taxa)) +
  scale_x_continuous(breaks = scales::pretty_breaks(n = 5)) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), legend.position="none") # turned off legend
pdf("diff_abund_hivstatus_v1vsv3.pdf")
ggplot(df, aes(x = x, y = taxa)) +
  geom_vline(xintercept = 0, color = "gray50", lty = "dashed",
                          alpha = 0.75, lwd = 1) +
  geom_point() +
  geom_errorbarh(aes(xmin = xmin, xmax = xmax, colour = xmin<=0 & xmax <= 0| xmin>=0 & xmax >= 0), height = .3) +
  theme_bw() +
  facet_wrap(~variable, scales = "free_x", nrow = 1) +
  labs(title = "", x = "", y = "Taxa") +
  scale_y_discrete(limits = rev(df$taxa)) +
  scale_x_continuous(breaks = scales::pretty_breaks(n = 5)) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), legend.position="none") # turned off legend
dev.off()
# Out:
# png
#   2
# plot without title
